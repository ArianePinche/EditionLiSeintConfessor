# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: lxml in ./env/lib/python3.6/site-packages (from -r requirements.txt (line 1)) (4.4.2)
# Requirement already satisfied: jupyter in ./env/lib/python3.6/site-packages (from -r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: notebook in ./env/lib/python3.6/site-packages (from -r requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: bokeh in ./env/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (1.4.0)
# Collecting regex
#   Using cached regex-2020.1.8-cp36-cp36m-manylinux2010_x86_64.whl (689 kB)
# Requirement already satisfied: qtconsole in ./env/lib/python3.6/site-packages (from jupyter->-r requirements.txt (line 2)) (4.6.0)
# Requirement already satisfied: ipykernel in ./env/lib/python3.6/site-packages (from jupyter->-r requirements.txt (line 2)) (5.1.4)
# Requirement already satisfied: jupyter-console in ./env/lib/python3.6/site-packages (from jupyter->-r requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: ipywidgets in ./env/lib/python3.6/site-packages (from jupyter->-r requirements.txt (line 2)) (7.5.1)
# Requirement already satisfied: nbconvert in ./env/lib/python3.6/site-packages (from jupyter->-r requirements.txt (line 2)) (5.6.1)
# Requirement already satisfied: pyzmq>=17 in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (18.1.1)
# Requirement already satisfied: prometheus-client in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (0.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (4.6.1)
# Requirement already satisfied: ipython-genutils in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: terminado>=0.8.1 in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: Send2Trash in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: nbformat in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (5.0.4)
# Requirement already satisfied: jupyter-client>=5.3.4 in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (5.3.4)
# Requirement already satisfied: tornado>=5.0 in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (6.0.3)
# Requirement already satisfied: traitlets>=4.2.1 in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (4.3.3)
# Requirement already satisfied: jinja2 in ./env/lib/python3.6/site-packages (from notebook->-r requirements.txt (line 3)) (2.10.3)
# Requirement already satisfied: numpy>=1.7.1 in ./env/lib/python3.6/site-packages (from bokeh->-r requirements.txt (line 4)) (1.18.1)
# Requirement already satisfied: six>=1.5.2 in ./env/lib/python3.6/site-packages (from bokeh->-r requirements.txt (line 4)) (1.14.0)
# Requirement already satisfied: PyYAML>=3.10 in ./env/lib/python3.6/site-packages (from bokeh->-r requirements.txt (line 4)) (5.3)
# Requirement already satisfied: pillow>=4.0 in ./env/lib/python3.6/site-packages (from bokeh->-r requirements.txt (line 4)) (7.0.0)
# Requirement already satisfied: python-dateutil>=2.1 in ./env/lib/python3.6/site-packages (from bokeh->-r requirements.txt (line 4)) (2.8.1)
# Requirement already satisfied: packaging>=16.8 in ./env/lib/python3.6/site-packages (from bokeh->-r requirements.txt (line 4)) (20.1)
# Requirement already satisfied: pygments in ./env/lib/python3.6/site-packages (from qtconsole->jupyter->-r requirements.txt (line 2)) (2.5.2)
# Requirement already satisfied: ipython>=5.0.0 in ./env/lib/python3.6/site-packages (from ipykernel->jupyter->-r requirements.txt (line 2)) (7.11.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in ./env/lib/python3.6/site-packages (from jupyter-console->jupyter->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in ./env/lib/python3.6/site-packages (from ipywidgets->jupyter->-r requirements.txt (line 2)) (3.5.1)
# Requirement already satisfied: testpath in ./env/lib/python3.6/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.4.4)
# Requirement already satisfied: entrypoints>=0.2.2 in ./env/lib/python3.6/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.3)
# Requirement already satisfied: bleach in ./env/lib/python3.6/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: defusedxml in ./env/lib/python3.6/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in ./env/lib/python3.6/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./env/lib/python3.6/site-packages (from nbconvert->jupyter->-r requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: ptyprocess; os_name != "nt" in ./env/lib/python3.6/site-packages (from terminado>=0.8.1->notebook->-r requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in ./env/lib/python3.6/site-packages (from nbformat->notebook->-r requirements.txt (line 3)) (3.2.0)
# Requirement already satisfied: decorator in ./env/lib/python3.6/site-packages (from traitlets>=4.2.1->notebook->-r requirements.txt (line 3)) (4.4.1)
# Requirement already satisfied: MarkupSafe>=0.23 in ./env/lib/python3.6/site-packages (from jinja2->notebook->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in ./env/lib/python3.6/site-packages (from packaging>=16.8->bokeh->-r requirements.txt (line 4)) (2.4.6)
# Requirement already satisfied: backcall in ./env/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (0.1.0)
# Requirement already satisfied: jedi>=0.10 in ./env/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: pickleshare in ./env/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in ./env/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (45.1.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in ./env/lib/python3.6/site-packages (from ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: wcwidth in ./env/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->-r requirements.txt (line 2)) (0.1.8)
# Requirement already satisfied: webencodings in ./env/lib/python3.6/site-packages (from bleach->nbconvert->jupyter->-r requirements.txt (line 2)) (0.5.1)
# Requirement already satisfied: attrs>=17.4.0 in ./env/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->-r requirements.txt (line 3)) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in ./env/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->-r requirements.txt (line 3)) (0.15.7)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in ./env/lib/python3.6/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: parso>=0.5.2 in ./env/lib/python3.6/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->jupyter->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: zipp>=0.5 in ./env/lib/python3.6/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook->-r requirements.txt (line 3)) (2.1.0)
# Installing collected packages: regex
# Successfully installed regex-2020.1.8

# %%
from lxml import etree as ET
from bokeh.io import show, output_file
from bokeh.plotting import figure
import regex as re

# %%
with open("texte.xml") as f:
    xml = ET.parse(f)
    
counts = []
identifiers = []

manuscrit = "G1"
# Je récupère les @types et je les mets dans une liste de valeur unique (set) puis je les trie (sorted)
cats = sorted(list(set([str(x) for x in xml.xpath("//@type")])))

# Passage pour compter les mots
_punc = re.compile("([^<>/\w\s])")
_spaces = re.compile("([\s\u00a0]+)")

def count_words(text):
    text = _spaces.sub(" ", _punc.sub(" \1 ", text))
    return len(text.split()), text
# Fin des définitions d'outils pour compter les mots

# Pour chaque chapitre et chaque "pas" de chapitre (0, chapitre1), (1, chapitre2)
for chap_no, chap in enumerate(xml.xpath("./div")):
    chap_no += 1
    for sect_no, section in enumerate(chap.xpath("./div")):
        sect_no += 1
        for p_no, p in enumerate(section.xpath("./p")):
            p_no += 1
            # Création d'une chaine identifiant nb_chap.nb_sect.nb_p
            identifier = "{}.{}.{}".format(chap_no, sect_no, p_no)
            # J'ajoute aussi un numero sequentiel de paragraph: les paragraphes sont numérotés de 1 à la fin
            identifiers.append(len(identifiers) + 1)
            # Création du dictionnaire où il y aura les stats1
            stats = {
                "identifier": identifier,
                "neutral": 0,
                "edition": 0,
                manuscrit: 0,
                **{cat: 0 for cat in cats}
            }
            
            # Récupération du texte non-spécifique
            for text_node in p.xpath("./text()"):
                cnt, txt = count_words(str(text_node).strip())
                if cnt:
                    stats["neutral"] += cnt
            
            # Récupération du texte spécifique à l'Édition (et donc en contradiction avec autre manuscrit)
            for text_node in p.xpath("./choix/Edition/text()"):
                cnt, txt = count_words(str(text_node).strip())
                if cnt:
                    stats["edition"] += cnt
            
            # Pour calcul total, addition du spécifique à l'édition et du général
            stats["edition_real"] = stats["edition"] + stats["neutral"]
            
            # Et maintenant, par catégorie de type
            for manuscrit_var in p.xpath("./choix/{}".format(manuscrit)):
                cnt, txt = count_words(str(manuscrit_var.text).strip())
                if cnt:
                    # Je rajoute aussi en fonction de @type
                    stats[manuscrit_var.attrib["type"]] += cnt
                    # On ajoute aussi au général
                    stats[manuscrit] += cnt
            
            stats["diff"] = stats["edition"] - stats[manuscrit]
            counts.append(stats)

# %%
import csv

# On exporte le CSV
header = list(counts[0].keys())
with open("stats.csv", "w") as f:
    writer = csv.DictWriter(f, fieldnames=header)
    writer.writeheader()
    writer.writerows(counts)

# %%
# Revert the dict !


from bokeh.io import show, output_file
from bokeh.plotting import figure
from bokeh.palettes import all_palettes

output_file("bar_stacked.html")

# Remap data
data = {"identifier": [], **{cat: [] for cat in cats}}
psg_size = [psg["edition_real"] for psg in counts]
for psg_id, element in enumerate(counts):
    for key in data:
        if key != "identifier":
            data[key].append(element[key] / psg_size[psg_id])
        else:
            data[key].append(element[key]) 
        
data["identifier"] = [str(x) for x in identifiers]

# Trie les catégories dans l'ordre décroissant de décompte total
cats = sorted(cats, key=lambda x: -sum(data[x]))

# Plot
p = figure(x_range=data["identifier"], plot_width=1280, plot_height=800, title="Type of modification per passage",
           toolbar_location=None, tools="hover", tooltips="Var[type='$name'][p=@identifier]: @$name")
p.vbar_stack(cats, x='identifier', width=0.9, source=data, legend_label=cats, 
             color=all_palettes["Category20"][len(cats)])

#p.line(data["identifier"], psg_size, color='#000000', legend_label='Size of the edition passage')

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.axis.minor_tick_line_color = None
p.outline_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)
